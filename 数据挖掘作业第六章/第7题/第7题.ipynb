# %% [markdown]
# # 数据挖掘第六章作业 第7题

# %% [markdown]
# ## 读入数据

# %%
import pandas as pd
def load_data(path):
        data = pd.read_csv(path)
        num = data.iloc[:, -2]
        y = data.iloc[:, -1]

        return num, y

# 生成购物篮，每个订单作为一个集合
def getShoppingCart(orders, items):
    numOfOrder = len(set(orders))
    shoppingCart = [set() for _ in range(numOfOrder)]
    for j in range(len(orders)):
        shoppingCart[orders[j]-1].add(items[j])
    return shoppingCart

orders, items = load_data('data100.csv')
shoppingCart = getShoppingCart(orders, items)
print(shoppingCart)
# Out:
# [{'sandwich bags', 'dinner rolls', 'aluminum foil', 'soda', 'ice cream', 'flour', 'lunch meat', 'butter', 'pork', 'mixes', 'laundry detergent', 'beef', 'shampoo', 'soap', 'all- purpose', 'vegetables'}, {'sandwich bags', 'tortillas', 'waffles', 'cereals', 'aluminum foil', 'cheeses', 'dishwashing liquid/detergent', 'yogurt', 'milk', 'laundry detergent', 'shampoo', 'toilet paper', 'individual meals', 'mixes', 'vegetables', 'hand soap'}, {'cereals', 'spaghetti sauce', 'lunch meat', 'pork', 'laundry detergent', 'shampoo', 'sandwich loaves', 'soda', 'bagels', 'cheeses', 'milk', 'vegetables', 'hand soap', 'dinner rolls', 'ketchup', 'soap', 'ice cream', 'poultry', 'eggs', 'toilet paper'}, {'cereals', 'soda', 'lunch meat', 'all- purpose', 'juice', 'toilet paper'}, {'pasta', 'flour', 'spaghetti sauce', 'pork', 'individual meals', 'sandwich loaves', 'all- purpose', 'soda', 'yogurt', 'milk', 'mixes', 'vegetables', 'hand soap', 'dinner rolls', 'tortillas', 'waffles', 'poultry', 'eggs', 'paper towels', 'toilet paper'}, {'coffee/tea', 'cereals', 'pasta', 'spaghetti sauce', 'laundry detergent', 'shampoo', 'all- purpose', 'bagels', 'dishwashing liquid/detergent', 'milk', 'vegetables', 'aluminum foil', 'butter', 'ketchup', 'soap', 'eggs', 'poultry', 'paper towels', 'toilet paper'}, {'sandwich bags', 'pasta', 'spaghetti sauce', 'individual meals', 'all- purpose', 'dishwashing liquid/detergent', 'yogurt', 'milk', 'mixes', 'vegetables', 'beef', 'ketchup', 'soap', 'juice', 'tortillas', 'ice cream', 'eggs', 'paper towels', 'fruits', 'toilet paper'}, {'waffles', 'ice cream', 'soda', 'cheeses', 'poultry', 'vegetables', 'paper towels', 'juice', 'toilet paper'}, {'coffee/tea', 'dishwashing liquid/detergent', 'juice', 'poultry'}, {'coffee/tea', 'flour', 'lunch meat', 'pork', 'sandwich loaves', 'soda', 'bagels', 'cheeses', 'dishwashing liquid/detergent', 'milk', 'vegetables', 'beef', 'ketchup', 'soap', 'juice', 'sugar', 'tortillas', 'waffles', 'eggs', 'poultry', 'fruits', 'toilet paper'}, {'coffee/tea', 'pasta', 'flour', 'pork', 'shampoo', 'individual meals', 'sandwich loaves', 'soda', 'bagels', 'cheeses', 'dishwashing liquid/detergent', 'milk', 'vegetables', 'hand soap', 'dinner rolls', 'ketchup', 'sugar', 'waffles', 'ice cream', 'eggs', 'poultry', 'toilet paper'}, {'sugar', 'tortillas', 'waffles', 'bagels', 'pasta', 'spaghetti sauce', 'lunch meat', 'yogurt', 'pork', 'laundry detergent', 'butter', 'flour', 'shampoo', 'juice', 'vegetables', 'hand soap'}, {'sugar', 'aluminum foil', 'ice cream', 'bagels', 'flour', 'vegetables', 'pork', 'laundry detergent', 'shampoo', 'individual meals', 'sandwich loaves', 'soap', 'fruits', 'all- purpose', 'paper towels', 'juice', 'toilet paper'}, {'dinner rolls', 'sandwich bags', 'cereals', 'cheeses', 'laundry detergent', 'shampoo', 'ketchup', 'individual meals', 'sandwich loaves', 'fruits', 'vegetables'}, {'tortillas', 'cereals', 'ice cream', 'cheeses', 'bagels', 'aluminum foil', 'spaghetti sauce', 'lunch meat', 'butter', 'individual meals', 'sandwich loaves', 'paper towels', 'fruits', 'mixes', 'juice', 'toilet paper', 'hand soap'}, {'sugar', 'sandwich bags', 'dinner rolls', 'cereals', 'ice cream', 'soda', 'cheeses', 'pasta', 'flour', 'dishwashing liquid/detergent', 'milk', 'soap', 'beef', 'paper towels', 'juice'}, {'cereals', 'pasta', 'spaghetti sauce', 'milk', 'individual meals', 'sandwich loaves', 'hand soap'}, {'coffee/tea', 'sandwich bags', 'bagels', 'shampoo', 'toilet paper'}, {'coffee/tea', 'sugar', 'waffles', 'aluminum foil', 'eggs', 'bagels', 'flour', 'spaghetti sauce', 'butter', 'laundry detergent', 'beef', 'individual meals', 'juice', 'vegetables'}, {'coffee/tea', 'laundry detergent', 'shampoo', 'individual meals', 'sandwich loaves', 'cheeses', 'soda', 'dishwashing liquid/detergent', 'yogurt', 'mixes', 'vegetables', 'hand soap', 'aluminum foil', 'butter', 'beef', 'ketchup', 'soap', 'juice', 'sugar', 'tortillas', 'poultry', 'paper towels', 'toilet paper'}, {'waffles', 'bagels', 'mixes', 'pork', 'fruits', 'all- pu ...

# %% [markdown]
# ## Apriori算法

# %% [markdown]
# ### Apriori 算法的实现

# %%
FREQUENT = 30


class Apriori:

    # 判断itemList是否在order中
    def __contains(self, order, itemList):
        for item in itemList:
            if item not in order:
                return False
        return True

    # 计算itemList在shoppingCart中出现的次数
    def __count(self, itemList, shoppingCart):
        count = 0
        for order in shoppingCart:
            if (self.__contains(order, itemList)):
                count += 1
        return count

    # 生成下一层的itemList
    def __generate_next_itemList(self, itemList):
        next_itemList = []
        for i in range(len(itemList)):
            for j in range(i+1, len(itemList)):
                if itemList[i][:-1] == itemList[j][:-1]:
                    newList = [x for x in itemList[i]]
                    newList.append(itemList[j][-1])
                    next_itemList.append(newList)
        return next_itemList

    # 生成第一层的itemList
    def __getFirstItemLists(self, items):
        firstItemList = [[x] for x in set(items)]
        return firstItemList

    # 过滤掉不满足最小支持度的itemList
    def __filter(self, itemLists, shoppingCart):
        filterList = []
        for itemList in itemLists:
            if self.__count(itemList, shoppingCart) >= FREQUENT:
                filterList.append(itemList)
        return filterList

    # 主函数,也是对外接口
    def analyze(self, items, shoppingCart):
        itemLists = self.__getFirstItemLists(items)
        totalFrequentItemLists = []

        while len(itemLists) > 0:
            filteredItemLists = []
            filteredItemLists = self.__filter(itemLists, shoppingCart)
            if (len(filteredItemLists) > 0):
                totalFrequentItemLists.append(filteredItemLists)
            nextItemList = self.__generate_next_itemList(filteredItemLists)
            itemLists = nextItemList

        return totalFrequentItemLists

# %% [markdown]
# ### Apriori算法的使用

# %%
# 输出所有的频繁项集
ap = Apriori()
print(ap.analyze(items, shoppingCart))
# Out:
# [[['coffee/tea'], ['sandwich bags'], ['cereals'], ['pasta'], ['flour'], ['lunch meat'], ['spaghetti sauce'], ['pork'], ['laundry detergent'], ['shampoo'], ['individual meals'], ['sandwich loaves'], ['all- purpose'], ['soda'], ['cheeses'], ['bagels'], ['dishwashing liquid/detergent'], ['yogurt'], ['milk'], ['mixes'], ['vegetables'], ['hand soap'], ['dinner rolls'], ['aluminum foil'], ['butter'], ['beef'], ['ketchup'], ['soap'], ['juice'], ['sugar'], ['tortillas'], ['waffles'], ['ice cream'], ['poultry'], ['eggs'], ['paper towels'], ['fruits'], ['toilet paper']], [['coffee/tea', 'vegetables'], ['lunch meat', 'vegetables'], ['shampoo', 'vegetables'], ['sandwich loaves', 'vegetables'], ['all- purpose', 'vegetables'], ['soda', 'vegetables'], ['cheeses', 'vegetables'], ['vegetables', 'aluminum foil'], ['vegetables', 'beef'], ['vegetables', 'ketchup'], ['vegetables', 'waffles'], ['vegetables', 'ice cream'], ['vegetables', 'poultry']]]

# %% [markdown]
# ## FP-growth算法

# %% [markdown]
# ### FP-growth 算法的实现

# %%
FREQUENT = 30


class FPNode:
    # basic node in FP tree
    def __init__(self, name, count, parent):
        self.name = name
        self.count = count
        self.parent = parent
        self.children = {}
        self.sameNodeLink = None

    # add count to node
    def more(self, count):
        self.count += count


class FPAlgorithm:
    def __init__(self, minSup):
        self.minSup = minSup

    # 将原始事务集转换为字典形式

    def createInitSet(self, dataSet):
        retDict = {}
        for trans in dataSet:
            retDict[frozenset(trans)] = 1
        return retDict

    # 同一个元素的链表，尾插法
    def updateHeader(self, nodeToTest, targetNode):
        while (nodeToTest.sameNodeLink is not None):
            nodeToTest = nodeToTest.sameNodeLink
        nodeToTest.sameNodeLink = targetNode

    # 追踪一条路径
    def ascendTree(self, leafNode, prefixPath):
        if leafNode.parent is not None:
            prefixPath.append(leafNode.name)
            self.ascendTree(leafNode.parent, prefixPath)

    def findPrefixPath(self, basePat, treeNode):
        condPats = {}
        while treeNode is not None:
            prefixPath = []
            self.ascendTree(treeNode, prefixPath)
            if len(prefixPath) > 1:
                condPats[frozenset(prefixPath[1:])] = treeNode.count
            treeNode = treeNode.sameNodeLink
        return condPats

    def updateTree(self, items, inTree, headerTable, count):
        if items[0] in inTree.children:
            inTree.children[items[0]].more(count)
        else:
            inTree.children[items[0]] = FPNode(items[0], count, inTree)
            if headerTable[items[0]][1] is None:
                headerTable[items[0]][1] = inTree.children[items[0]]
            else:
                self.updateHeader(headerTable[items[0]][1],
                                  inTree.children[items[0]])

        if len(items) > 1:
            self.updateTree(items[1:], inTree.children[items[0]],
                            headerTable, count)

    def createTree(self, dataset):
        headerTable = {}
        for order in dataset:
            for item in order:
                headerTable[item] = headerTable.get(item, 0) + 1

        for k in list(headerTable.keys()):
            if headerTable[k] < FREQUENT:
                del (headerTable[k])

        freqItemSet = set(headerTable.keys())
        if len(freqItemSet) == 0:
            return None, None

        for k in headerTable:
            headerTable[k] = [headerTable[k], None]

        root = FPNode('Null Set', 1, None)

        for tran, count in dataset.items():
            localD = {}
            for item in tran:
                if item in freqItemSet:
                    localD[item] = headerTable[item][0]
            if len(localD) > 0:
                orderedItems = [v[0]
                                for v in sorted(localD.items(), key=lambda p:p[1], reverse=True)]
                self.updateTree(orderedItems, root, headerTable, count)

        return root, headerTable

    def mineTree(self, inTree, headerTable, minSup, preFix, freqItemList):
        bigL = [v[0]
                for v in sorted(headerTable.items(), key=lambda p:str(p[1]))]
        for basePat in bigL:
            newFreqSet = preFix.copy()
            newFreqSet.add(basePat)

            freqItemList.append(newFreqSet)
            condPattBases = self.findPrefixPath(
                basePat, headerTable[basePat][1])
            myCondTree, myHead = self.createTree(condPattBases)
            if myHead is not None:
                self.mineTree(myCondTree, myHead, minSup,
                              newFreqSet, freqItemList)

    def analyse(self, shoppingCart):
        self.trans = shoppingCart
        self.dataset = self.createInitSet(shoppingCart)
        root, headerTable = self.createTree(self.dataset)
        freqItemList = []
        self.mineTree(root, headerTable, FREQUENT, set([]), freqItemList)
        return freqItemList

# %% [markdown]
# ### FP-growth 算法的使用

# %%
fp = FPAlgorithm(FREQUENT)
print(fp.analyse(shoppingCart))
# Out:
# [{'yogurt'}, {'flour'}, {'soap'}, {'dinner rolls'}, {'laundry detergent'}, {'sandwich bags'}, {'milk'}, {'butter'}, {'eggs'}, {'dishwashing liquid/detergent'}, {'tortillas'}, {'pork'}, {'spaghetti sauce'}, {'coffee/tea'}, {'coffee/tea', 'vegetables'}, {'pasta'}, {'sugar'}, {'waffles'}, {'waffles', 'vegetables'}, {'hand soap'}, {'aluminum foil'}, {'vegetables', 'aluminum foil'}, {'paper towels'}, {'all- purpose'}, {'all- purpose', 'vegetables'}, {'cereals'}, {'mixes'}, {'ice cream'}, {'vegetables', 'ice cream'}, {'lunch meat'}, {'lunch meat', 'vegetables'}, {'individual meals'}, {'toilet paper'}, {'bagels'}, {'fruits'}, {'sandwich loaves'}, {'beef'}, {'ketchup'}, {'shampoo'}, {'juice'}, {'poultry'}, {'soda'}, {'cheeses'}, {'vegetables'}]

# %% [markdown]
# ## ECLAT算法

# %% [markdown]
# ### ECLAT算法的实现

# %%
FREQUENT = 30


class Eclat:

    def __init__(self, min_support=FREQUENT, max_items=2):
        self.min_support = min_support
        self.max_items = max_items
        self.result = []
        self.itemDict = {}

    def fit(self, transactions):
        self.transactions = transactions
        self.num_transactions = len(transactions)
        self._get_items()

    def _get_items(self):
        items = []
        k = 0
        for transaction in self.transactions:
            k += 1
            for item in transaction:
                if([item] not in items):
                    items.append([item])
                if(frozenset([item]) not in self.itemDict):
                    self.itemDict[frozenset([item])] = set()
                self.itemDict[frozenset([item])].add(k)
        self.items = sorted(list(items))
        self.filter(self.itemDict, self.items)

    def filter(self, itemDict, keys):
        for key in keys:
            if(len(itemDict[frozenset(key)]) < self.min_support):
                del itemDict[frozenset(key)]
            else:
                self.result.append(key)
        return itemDict

    def _get_frequent_itemsets(self):
        nextRound = self.items
        for i in range(0, self.max_items):
            nextRound = self.__generate_next_itemList(nextRound)
            self.itemDict = self.filter(self.itemDict, nextRound)
            if not nextRound:
                break 
        return self.result
        
    def __generate_next_itemList(self, itemList):
        next_itemList = []
        for i in range(len(itemList)):
            for j in range(i+1, len(itemList)):
                if ((itemList[i][:-1] == itemList[j][:-1]) and (self.itemDict.get(frozenset(itemList[i]), {})) and (self.itemDict.get(frozenset(itemList[j]), {}))):
                    newList = [x for x in itemList[i]]
                    newList.append(itemList[j][-1])
                    next_itemList.append(newList)
                    self.itemDict[frozenset(newList)] = self.itemDict[frozenset(itemList[i])].intersection(self.itemDict[frozenset(itemList[j])])
        return next_itemList

# %% [markdown]
# ### ECLAT算法的使用

# %%
def get_frequent_itemsets(shoppingCart):
    transactions = shoppingCart
    eclat = Eclat(min_support=FREQUENT, max_items=2)
    eclat.fit(transactions)
    frequent_itemsets = eclat._get_frequent_itemsets()
    print("final result:", frequent_itemsets)


get_frequent_itemsets(shoppingCart)
# Out:
# final result: [['all- purpose'], ['aluminum foil'], ['bagels'], ['beef'], ['butter'], ['cereals'], ['cheeses'], ['coffee/tea'], ['dinner rolls'], ['dishwashing liquid/detergent'], ['eggs'], ['flour'], ['fruits'], ['hand soap'], ['ice cream'], ['individual meals'], ['juice'], ['ketchup'], ['laundry detergent'], ['lunch meat'], ['milk'], ['mixes'], ['paper towels'], ['pasta'], ['pork'], ['poultry'], ['sandwich bags'], ['sandwich loaves'], ['shampoo'], ['soap'], ['soda'], ['spaghetti sauce'], ['sugar'], ['toilet paper'], ['tortillas'], ['vegetables'], ['waffles'], ['yogurt'], ['all- purpose', 'vegetables'], ['aluminum foil', 'vegetables'], ['beef', 'vegetables'], ['cheeses', 'vegetables'], ['coffee/tea', 'vegetables'], ['ice cream', 'vegetables'], ['ketchup', 'vegetables'], ['lunch meat', 'vegetables'], ['poultry', 'vegetables'], ['sandwich loaves', 'vegetables'], ['shampoo', 'vegetables'], ['soda', 'vegetables'], ['vegetables', 'waffles']]

# %% [markdown]
# ## 不同数据集上运行时间的比较实验

# %% [markdown]
# ### 100个事务

# %%
import time

# on 100 trans

start = time.time()
ap = Apriori()
print(ap.analyze(items, shoppingCart))
end = time.time()
print("Apriori time on 100 trans:", (end - start) * 1000)

start = time.time()
fp = FPAlgorithm(FREQUENT)
print(fp.analyse(shoppingCart))
end = time.time()
print("FP-growth time on 100 trans:", (end - start) * 1000)

start = time.time()
get_frequent_itemsets(shoppingCart)
end = time.time()
print("ECLAT time on 100 trans:", (end - start) * 1000)
# Out:
# [[['coffee/tea'], ['sandwich bags'], ['cereals'], ['pasta'], ['flour'], ['lunch meat'], ['spaghetti sauce'], ['pork'], ['laundry detergent'], ['shampoo'], ['individual meals'], ['sandwich loaves'], ['all- purpose'], ['soda'], ['cheeses'], ['bagels'], ['dishwashing liquid/detergent'], ['yogurt'], ['milk'], ['mixes'], ['vegetables'], ['hand soap'], ['dinner rolls'], ['aluminum foil'], ['butter'], ['beef'], ['ketchup'], ['soap'], ['juice'], ['sugar'], ['tortillas'], ['waffles'], ['ice cream'], ['poultry'], ['eggs'], ['paper towels'], ['fruits'], ['toilet paper']], [['coffee/tea', 'vegetables'], ['lunch meat', 'vegetables'], ['shampoo', 'vegetables'], ['sandwich loaves', 'vegetables'], ['all- purpose', 'vegetables'], ['soda', 'vegetables'], ['cheeses', 'vegetables'], ['vegetables', 'aluminum foil'], ['vegetables', 'beef'], ['vegetables', 'ketchup'], ['vegetables', 'waffles'], ['vegetables', 'ice cream'], ['vegetables', 'poultry']]]
# Apriori time on 100 trans: 10.969161987304688
# [{'yogurt'}, {'soap'}, {'flour'}, {'sandwich bags'}, {'laundry detergent'}, {'milk'}, {'dinner rolls'}, {'butter'}, {'eggs'}, {'spaghetti sauce'}, {'pork'}, {'dishwashing liquid/detergent'}, {'tortillas'}, {'coffee/tea'}, {'coffee/tea', 'vegetables'}, {'aluminum foil'}, {'vegetables', 'aluminum foil'}, {'waffles'}, {'waffles', 'vegetables'}, {'hand soap'}, {'paper towels'}, {'pasta'}, {'sugar'}, {'cereals'}, {'mixes'}, {'all- purpose'}, {'all- purpose', 'vegetables'}, {'fruits'}, {'individual meals'}, {'toilet paper'}, {'bagels'}, {'ice cream'}, {'vegetables', 'ice cream'}, {'lunch meat'}, {'lunch meat', 'vegetables'}, {'sandwich loaves'}, {'ketchup'}, {'beef'}, {'poultry'}, {'juice'}, {'shampoo'}, {'cheeses'}, {'soda'}, {'vegetables'}]
# FP-growth time on 100 trans: 8.023500442504883
# final result: [['all- purpose'], ['aluminum foil'], ['bagels'], ['beef'], ['butter'], ['cereals'], ['cheeses'], ['coffee/tea'], ['dinner rolls'], ['dishwashing liquid/detergent'], ['eggs'], ['flour'], ['fruits'], ['hand soap'], ['ice cream'], ['individual meals'], ['juice'], ['ketchup'], ['laundry detergent'], ['lunch meat'], ['milk'], ['mixes'], ['paper towels'], ['pasta'], ['pork'], ['poultry'], ['sandwich bags'], ['sandwich loaves'], ['shampoo'], ['soap'], ['soda'], ['spaghetti sauce'], ['sugar'], ['toilet paper'], ['tortillas'], ['vegetables'], ['waffles'], ['yogurt'], ['all- purpose', 'vegetables'], ['aluminum foil', 'vegetables'], ['beef', 'vegetables'], ['cheeses', 'vegetables'], ['coffee/tea', 'vegetables'], ['ice cream', 'vegetables'], ['ketchup', 'vegetables'], ['lunch meat', 'vegetables'], ['poultry', 'vegetables'], ['sandwich loaves', 'vegetables'], ['shampoo', 'vegetables'], ['soda', 'vegetables'], ['vegetables', 'waffles']]
# ECLAT time on 100 trans: 50.58002471923828

# %% [markdown]
# ### 300个事务

# %%
import time

# on 100 trans
orders, items = load_data('data300.csv')
bigCart = getShoppingCart(orders, items)

start = time.time()
ap = Apriori()
print(ap.analyze(items, bigCart))
end = time.time()
print("Apriori time on 300 trans:", (end - start) * 1000)

start = time.time()
fp = FPAlgorithm(FREQUENT)
print(fp.analyse(bigCart))
end = time.time()
print("FP-growth time on 300 trans:", (end - start) * 1000)

start = time.time()
get_frequent_itemsets(bigCart)
end = time.time()
print("ECLAT time on 300 trans:", (end - start) * 1000)
# Out:
# [[['coffee/tea'], ['sandwich bags'], ['cereals'], ['pasta'], ['flour'], ['lunch meat'], ['spaghetti sauce'], ['pork'], ['laundry detergent'], ['shampoo'], ['individual meals'], ['sandwich loaves'], ['all- purpose'], ['soda'], ['cheeses'], ['bagels'], ['dishwashing liquid/detergent'], ['yogurt'], ['milk'], ['mixes'], ['vegetables'], ['hand soap'], ['dinner rolls'], ['aluminum foil'], ['butter'], ['beef'], ['ketchup'], ['soap'], ['juice'], ['sugar'], ['tortillas'], ['waffles'], ['ice cream'], ['poultry'], ['eggs'], ['paper towels'], ['fruits'], ['toilet paper']], [['coffee/tea', 'sandwich bags'], ['coffee/tea', 'cereals'], ['coffee/tea', 'pasta'], ['coffee/tea', 'flour'], ['coffee/tea', 'lunch meat'], ['coffee/tea', 'spaghetti sauce'], ['coffee/tea', 'pork'], ['coffee/tea', 'laundry detergent'], ['coffee/tea', 'shampoo'], ['coffee/tea', 'individual meals'], ['coffee/tea', 'sandwich loaves'], ['coffee/tea', 'all- purpose'], ['coffee/tea', 'soda'], ['coffee/tea', 'cheeses'], ['coffee/tea', 'bagels'], ['coffee/tea', 'dishwashing liquid/detergent'], ['coffee/tea', 'yogurt'], ['coffee/tea', 'milk'], ['coffee/tea', 'mixes'], ['coffee/tea', 'vegetables'], ['coffee/tea', 'hand soap'], ['coffee/tea', 'dinner rolls'], ['coffee/tea', 'aluminum foil'], ['coffee/tea', 'butter'], ['coffee/tea', 'beef'], ['coffee/tea', 'ketchup'], ['coffee/tea', 'soap'], ['coffee/tea', 'juice'], ['coffee/tea', 'sugar'], ['coffee/tea', 'tortillas'], ['coffee/tea', 'waffles'], ['coffee/tea', 'ice cream'], ['coffee/tea', 'poultry'], ['coffee/tea', 'eggs'], ['coffee/tea', 'paper towels'], ['coffee/tea', 'fruits'], ['coffee/tea', 'toilet paper'], ['sandwich bags', 'cereals'], ['sandwich bags', 'pasta'], ['sandwich bags', 'flour'], ['sandwich bags', 'lunch meat'], ['sandwich bags', 'spaghetti sauce'], ['sandwich bags', 'pork'], ['sandwich bags', 'laundry detergent'], ['sandwich bags', 'shampoo'], ['sandwich bags', 'individual meals'], ['sandwich bags', 'sandwich loaves'], ['sandwich bags', 'all- purpose'], ['sandwich bags', 'soda'], ['sandwich bags', 'cheeses'], ['sandwich bags', 'bagels'], ['sandwich bags', 'dishwashing liquid/detergent'], ['sandwich bags', 'yogurt'], ['sandwich bags', 'milk'], ['sandwich bags', 'mixes'], ['sandwich bags', 'vegetables'], ['sandwich bags', 'hand soap'], ['sandwich bags', 'dinner rolls'], ['sandwich bags', 'aluminum foil'], ['sandwich bags', 'butter'], ['sandwich bags', 'beef'], ['sandwich bags', 'ketchup'], ['sandwich bags', 'soap'], ['sandwich bags', 'juice'], ['sandwich bags', 'tortillas'], ['sandwich bags', 'waffles'], ['sandwich bags', 'ice cream'], ['sandwich bags', 'poultry'], ['sandwich bags', 'eggs'], ['sandwich bags', 'paper towels'], ['sandwich bags', 'fruits'], ['sandwich bags', 'toilet paper'], ['cereals', 'pasta'], ['cereals', 'flour'], ['cereals', 'lunch meat'], ['cereals', 'spaghetti sauce'], ['cereals', 'pork'], ['cereals', 'laundry detergent'], ['cereals', 'shampoo'], ['cereals', 'individual meals'], ['cereals', 'sandwich loaves'], ['cereals', 'all- purpose'], ['cereals', 'soda'], ['cereals', 'cheeses'], ['cereals', 'bagels'], ['cereals', 'dishwashing liquid/detergent'], ['cereals', 'yogurt'], ['cereals', 'milk'], ['cereals', 'mixes'], ['cereals', 'vegetables'], ['cereals', 'hand soap'], ['cereals', 'dinner rolls'], ['cereals', 'aluminum foil'], ['cereals', 'butter'], ['cereals', 'beef'], ['cereals', 'ketchup'], ['cereals', 'soap'], ['cereals', 'juice'], ['cereals', 'sugar'], ['cereals', 'tortillas'], ['cereals', 'waffles'], ['cereals', 'ice cream'], ['cereals', 'poultry'], ['cereals', 'eggs'], ['cereals', 'paper towels'], ['cereals', 'fruits'], ['cereals', 'toilet paper'], ['pasta', 'flour'], ['pasta', 'lunch meat'], ['pasta', 'spaghetti sauce'], ['pasta', 'pork'], ['pasta', 'laundry detergent'], ['pasta', 'shampoo'], ['pasta', 'individual meals'], ['pasta', 'sandwich loaves'], ['pasta', 'all- purpose'], ['pasta', 'soda'], ['pasta', 'cheeses'], ['pasta', 'bagels'], ['pasta', 'dishwashing liquid/detergent'], ['pasta ...
# Apriori time on 300 trans: 539.5002365112305
# [{'sandwich bags'}, {'sandwich bags', 'soda'}, {'sandwich bags', 'lunch meat'}, {'sandwich bags', 'lunch meat', 'vegetables'}, {'sandwich bags', 'juice'}, {'sandwich bags', 'juice', 'vegetables'}, {'sandwich bags', 'flour'}, {'sandwich bags', 'flour', 'vegetables'}, {'sandwich bags', 'dishwashing liquid/detergent'}, {'sandwich bags', 'dishwashing liquid/detergent', 'vegetables'}, {'sandwich bags', 'aluminum foil'}, {'sandwich bags', 'vegetables', 'aluminum foil'}, {'coffee/tea', 'sandwich bags'}, {'coffee/tea', 'sandwich bags', 'vegetables'}, {'sandwich bags', 'sandwich loaves'}, {'sandwich bags', 'vegetables', 'sandwich loaves'}, {'sandwich bags', 'yogurt'}, {'sandwich bags', 'yogurt', 'vegetables'}, {'sandwich bags', 'individual meals'}, {'sandwich bags', 'vegetables', 'individual meals'}, {'sandwich bags', 'toilet paper'}, {'sandwich bags', 'eggs'}, {'sandwich bags', 'vegetables', 'eggs'}, {'bagels', 'sandwich bags'}, {'bagels', 'sandwich bags', 'vegetables'}, {'sandwich bags', 'dinner rolls'}, {'sandwich bags', 'vegetables', 'dinner rolls'}, {'sandwich bags', 'butter'}, {'sandwich bags', 'vegetables', 'butter'}, {'sandwich bags', 'pork'}, {'sandwich bags', 'vegetables', 'pork'}, {'sandwich bags', 'waffles'}, {'sandwich bags', 'waffles', 'vegetables'}, {'sandwich bags', 'hand soap'}, {'sandwich bags', 'vegetables', 'hand soap'}, {'fruits', 'sandwich bags'}, {'fruits', 'sandwich bags', 'vegetables'}, {'sandwich bags', 'mixes'}, {'sandwich bags', 'mixes', 'vegetables'}, {'sandwich bags', 'tortillas'}, {'sandwich bags', 'vegetables', 'tortillas'}, {'sandwich bags', 'cereals'}, {'sandwich bags', 'cereals', 'vegetables'}, {'sandwich bags', 'shampoo'}, {'sandwich bags', 'shampoo', 'vegetables'}, {'sandwich bags', 'milk'}, {'sandwich bags', 'vegetables', 'milk'}, {'pasta', 'sandwich bags'}, {'pasta', 'sandwich bags', 'vegetables'}, {'sandwich bags', 'spaghetti sauce'}, {'sandwich bags', 'spaghetti sauce', 'vegetables'}, {'sandwich bags', 'cheeses'}, {'sandwich bags', 'vegetables', 'cheeses'}, {'sandwich bags', 'paper towels'}, {'sandwich bags', 'vegetables', 'paper towels'}, {'sandwich bags', 'laundry detergent'}, {'sandwich bags', 'soap'}, {'sandwich bags', 'poultry'}, {'sandwich bags', 'ice cream'}, {'beef', 'sandwich bags'}, {'sandwich bags', 'all- purpose'}, {'sandwich bags', 'ketchup'}, {'sandwich bags', 'vegetables'}, {'laundry detergent'}, {'coffee/tea', 'laundry detergent'}, {'paper towels', 'laundry detergent'}, {'soda', 'laundry detergent'}, {'soda', 'vegetables', 'laundry detergent'}, {'tortillas', 'laundry detergent'}, {'bagels', 'laundry detergent'}, {'pasta', 'laundry detergent'}, {'pork', 'laundry detergent'}, {'waffles', 'laundry detergent'}, {'sugar', 'laundry detergent'}, {'sugar', 'vegetables', 'laundry detergent'}, {'sandwich loaves', 'laundry detergent'}, {'vegetables', 'sandwich loaves', 'laundry detergent'}, {'beef', 'laundry detergent'}, {'ice cream', 'laundry detergent'}, {'vegetables', 'ice cream', 'laundry detergent'}, {'eggs', 'laundry detergent'}, {'fruits', 'laundry detergent'}, {'fruits', 'vegetables', 'laundry detergent'}, {'aluminum foil', 'laundry detergent'}, {'vegetables', 'aluminum foil', 'laundry detergent'}, {'mixes', 'laundry detergent'}, {'mixes', 'vegetables', 'laundry detergent'}, {'all- purpose', 'laundry detergent'}, {'all- purpose', 'vegetables', 'laundry detergent'}, {'yogurt', 'laundry detergent'}, {'yogurt', 'vegetables', 'laundry detergent'}, {'poultry', 'laundry detergent'}, {'poultry', 'vegetables', 'laundry detergent'}, {'dinner rolls', 'laundry detergent'}, {'dinner rolls', 'vegetables', 'laundry detergent'}, {'toilet paper', 'laundry detergent'}, {'vegetables', 'toilet paper', 'laundry detergent'}, {'juice', 'laundry detergent'}, {'juice', 'vegetables', 'laundry detergent'}, {'flour', 'laundry detergent'}, {'flour', 'vegetables', 'laundry detergent'}, {'butter', 'laundry detergent'}, {'vegetables', 'butter', 'laundry detergent'}, {'soap', 'laundry detergent'}, {'vegetables', ' ...
# FP-growth time on 300 trans: 216.49646759033203
# final result: [['all- purpose'], ['aluminum foil'], ['bagels'], ['beef'], ['butter'], ['cereals'], ['cheeses'], ['coffee/tea'], ['dinner rolls'], ['dishwashing liquid/detergent'], ['eggs'], ['flour'], ['fruits'], ['hand soap'], ['ice cream'], ['individual meals'], ['juice'], ['ketchup'], ['laundry detergent'], ['lunch meat'], ['milk'], ['mixes'], ['paper towels'], ['pasta'], ['pork'], ['poultry'], ['sandwich bags'], ['sandwich loaves'], ['shampoo'], ['soap'], ['soda'], ['spaghetti sauce'], ['sugar'], ['toilet paper'], ['tortillas'], ['vegetables'], ['waffles'], ['yogurt'], ['all- purpose', 'aluminum foil'], ['all- purpose', 'bagels'], ['all- purpose', 'beef'], ['all- purpose', 'butter'], ['all- purpose', 'cereals'], ['all- purpose', 'cheeses'], ['all- purpose', 'coffee/tea'], ['all- purpose', 'dinner rolls'], ['all- purpose', 'dishwashing liquid/detergent'], ['all- purpose', 'eggs'], ['all- purpose', 'flour'], ['all- purpose', 'fruits'], ['all- purpose', 'hand soap'], ['all- purpose', 'ice cream'], ['all- purpose', 'individual meals'], ['all- purpose', 'juice'], ['all- purpose', 'ketchup'], ['all- purpose', 'laundry detergent'], ['all- purpose', 'lunch meat'], ['all- purpose', 'milk'], ['all- purpose', 'mixes'], ['all- purpose', 'paper towels'], ['all- purpose', 'pasta'], ['all- purpose', 'pork'], ['all- purpose', 'poultry'], ['all- purpose', 'sandwich bags'], ['all- purpose', 'sandwich loaves'], ['all- purpose', 'shampoo'], ['all- purpose', 'soap'], ['all- purpose', 'soda'], ['all- purpose', 'spaghetti sauce'], ['all- purpose', 'sugar'], ['all- purpose', 'toilet paper'], ['all- purpose', 'tortillas'], ['all- purpose', 'vegetables'], ['all- purpose', 'waffles'], ['all- purpose', 'yogurt'], ['aluminum foil', 'bagels'], ['aluminum foil', 'beef'], ['aluminum foil', 'butter'], ['aluminum foil', 'cereals'], ['aluminum foil', 'cheeses'], ['aluminum foil', 'coffee/tea'], ['aluminum foil', 'dinner rolls'], ['aluminum foil', 'dishwashing liquid/detergent'], ['aluminum foil', 'eggs'], ['aluminum foil', 'flour'], ['aluminum foil', 'fruits'], ['aluminum foil', 'hand soap'], ['aluminum foil', 'ice cream'], ['aluminum foil', 'individual meals'], ['aluminum foil', 'juice'], ['aluminum foil', 'ketchup'], ['aluminum foil', 'laundry detergent'], ['aluminum foil', 'lunch meat'], ['aluminum foil', 'milk'], ['aluminum foil', 'mixes'], ['aluminum foil', 'paper towels'], ['aluminum foil', 'pasta'], ['aluminum foil', 'pork'], ['aluminum foil', 'poultry'], ['aluminum foil', 'sandwich bags'], ['aluminum foil', 'sandwich loaves'], ['aluminum foil', 'shampoo'], ['aluminum foil', 'soap'], ['aluminum foil', 'soda'], ['aluminum foil', 'spaghetti sauce'], ['aluminum foil', 'sugar'], ['aluminum foil', 'toilet paper'], ['aluminum foil', 'tortillas'], ['aluminum foil', 'vegetables'], ['aluminum foil', 'waffles'], ['aluminum foil', 'yogurt'], ['bagels', 'beef'], ['bagels', 'butter'], ['bagels', 'cereals'], ['bagels', 'cheeses'], ['bagels', 'coffee/tea'], ['bagels', 'dinner rolls'], ['bagels', 'dishwashing liquid/detergent'], ['bagels', 'eggs'], ['bagels', 'flour'], ['bagels', 'fruits'], ['bagels', 'hand soap'], ['bagels', 'ice cream'], ['bagels', 'individual meals'], ['bagels', 'juice'], ['bagels', 'ketchup'], ['bagels', 'laundry detergent'], ['bagels', 'lunch meat'], ['bagels', 'milk'], ['bagels', 'mixes'], ['bagels', 'paper towels'], ['bagels', 'pasta'], ['bagels', 'pork'], ['bagels', 'poultry'], ['bagels', 'sandwich bags'], ['bagels', 'sandwich loaves'], ['bagels', 'shampoo'], ['bagels', 'soap'], ['bagels', 'soda'], ['bagels', 'spaghetti sauce'], ['bagels', 'sugar'], ['bagels', 'toilet paper'], ['bagels', 'tortillas'], ['bagels', 'vegetables'], ['bagels', 'waffles'], ['bagels', 'yogurt'], ['beef', 'butter'], ['beef', 'cereals'], ['beef', 'cheeses'], ['beef', 'coffee/tea'], ['beef', 'dinner rolls'], ['beef', 'dishwashing liquid/detergent'], ['beef', 'eggs'], ['beef', 'flour'], ['beef', 'fruits'], ['beef', 'hand soap'], ['beef', 'ice cream'], ['beef', 'individu ...
# ECLAT time on 300 trans: 103.97529602050781

# %% [markdown]
# ### 上面的实验结果是相当显著的，可以看出在大数据集上，ECLAT算法的效率是最高的，其次是FP-growth算法，最后是Apriori算法。然而在小数据集上，ECLAT落后于另外两者。这是因为ECLAT常数开销大，但复杂度低，而Apriori常数开销小，但复杂度高。而FP-growth算法介于两者之间。

# %% [markdown]
# ## 三种算法的原理与性能比较

# %% [markdown]
# 1. Apriori基于连接，它自底向上，通过多次扫描数据库并应用最小支持度阈值来生成频繁项集。但是它的时间和内存成本开销比较大。
#
# 1. FP-tree基于树，它使用将数据库压缩为FP-tree，保留了项集关联信息。不需要再次扫描数据库。它更快更高效，特别是对于稀疏数据集。然而，它仍然可能生成大量的条件FP-tree，消耗内存。
#
# 1. ECLAT基于模式增长，它适用于密集数据集或低最小支持度阈值。然而，它可能在处理高维数据集时，造成高内存消耗。
#
# 这些算法的性能取决于各种因素，如数据大小，数据分布，最小支持度阈值和模式密度等等，在某些情形下一种算法可能好于另外的算法。
# - Apriori适用于小型或稀疏数据集，具有高最小支持度阈值和低模式密度。
#
# - FP-tree适用于大型或稀疏数据集，具有中等最小支持度阈值和中等模式密度。
#
# - ECLAT适用于大型或密集数据集，具有低最小支持度阈值和高模式密度。
